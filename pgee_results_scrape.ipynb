# %%
import pandas as pd 
import numpy as np
import requests
from sqlalchemy import create_engine

# %%
# Define the range of seasons and suffixes
seasons = np.arange(2024,2014,-1,'object')
suffixes = [f"{season}dru" for season in seasons]

# Base URL
url = 'https://node.gurustats.usermd.net:60519/pgee'


with requests.Session() as session:
    frames = []
    for suffix in suffixes:
        full_url = f"{url}{suffix}"

        try:
            # Make a GET request and check if the request is successful
            response = session.get(full_url)
            response.raise_for_status() # Raise an error for bad status codes

            response = session.get(full_url)
            response.raise_for_status()

            # Parse the JSON response
            data = response.json()

            # Ensure 'data' key exists in the response
            if 'data' in data:
                sesason = suffix[:4]
                df = pd.DataFrame(data['data'])
                df.insert(1,"Sezon",sesason)
                frames.append(df)
            else:
                print(f"No 'data' key found in the response for {suffix}")
        
        except requests.RequestException as e:
            print(f"Request failed for {suffix}: {e}")
        except ValueError:
            print(f"Failed to parse JSON for {suffix}")

# Concatenate all dataframes
if frames:
    df_pgee = pd.concat(frames,ignore_index=True)
    print("Data successfully concatenated!")
else:
    print("No dataframes to concatenate.")
# Out:
# Data successfully concatenated!

# %%
df_pgee
# Out:
#                          _id Sezon                            KLUB  PKTTABELA  \
# 0   67045bb8cc786ae94f25f289  2024                         Wrocław         19
# 1   67045bb8cc786ae94f25f28a  2024                          Leszno         11
# 2   67045bb8cc786ae94f25f28b  2024                          Gorzów         19
# 3   67045bb8cc786ae94f25f28c  2024                       Grudziądz         14
# 4   67045bb8cc786ae94f25f28d  2024                           Toruń         15
# ..                       ...   ...                             ...        ...
# 75  5ac22d870b3a2dd84a4dd7a6  2015          MRGARDEN GKM Grudziądz         10
# 76  5ac22d870b3a2dd84a4dd7a7  2015                PGE Stal Rzeszów         13
# 77  5ac22d870b3a2dd84a4dd7a8  2015  MONEYmakesMONEY.pl Stal Gorzów         13
# 78  5ac22d870b3a2dd84a4dd7a9  2015                     Unia Tarnów         21
# 79  5ac22d870b3a2dd84a4dd7aa  2015       Spar Falubaz Zielona Góra         16
#
#    BONTABELA  PKTZDOBYTE  PKTSTRACONE  PLUSMINUS   Z  R  ...  DYSTPOR  \
# 0          4         920          878         42  11  1  ...    121.0
# 1                    586          673        -87   5  1  ...    110.0
# 2          3         848          860        -52  10     ...    135.0
# 3          2         641          677        -76   6     ...     84.0
# 4          3         889          909        -20   9     ...    117.0
# ..       ...         ...          ...        ...  .. ..  ...      ...
# 75         0         537          721       -184   5  0  ...      NaN
# 76         2         615          641        -26   5  1  ...      NaN
# 77         3         634          624         10   5  0  ...      NaN
# 78         4         827          792         35  11  1  ...      NaN
# 79         3         627          628         -1   6  1  ...      NaN
#
#     STARTBIL  DYSTBIL  MSCTABELA    id  liczba zm takt  śr pkt takt  \
# 0       25.0      9.0        2.0   4.0             NaN          NaN
# 1      -76.0     -2.0        8.0   5.0             NaN          NaN
# 2       50.0    -27.0        4.0  10.0             NaN          NaN
# 3      -20.0    -13.0        5.0   1.0             NaN          NaN
# 4     -106.0     38.0        3.0  14.0             NaN          NaN
# ..       ...      ...        ...   ...             ...          ...
# 75       NaN      NaN        NaN   NaN             NaN          NaN
# 76       NaN      NaN        NaN   NaN             NaN          NaN
# 77       NaN      NaN        NaN   NaN             NaN          NaN
# 78       NaN      NaN        NaN   NaN             NaN          NaN
# 79       NaN      NaN        NaN   NaN             NaN          NaN
#
#     liczba zm zwyklych  śr pkt zwyklych  MSC TABELA
# 0                  NaN              NaN         NaN
# 1                  NaN              NaN         NaN
# 2                  NaN              NaN         NaN
# 3                  NaN              NaN         NaN
# 4                  NaN              NaN         NaN
# ..                 ...              ...         ...
# 75                 NaN              NaN         NaN
# 76                 NaN              NaN         NaN
# 77                 NaN              NaN         NaN
# 78                 NaN              NaN         NaN
# 79                 NaN              NaN         NaN
#
# [80 rows x 42 columns]

# %%
df_pgee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   _id                 80 non-null     object
#  1   Sezon               80 non-null     object
#  2   KLUB                80 non-null     object
#  3   PKTTABELA           80 non-null     int64
#  4   BONTABELA           80 non-null     object
#  5   PKTZDOBYTE          80 non-null     int64
#  6   PKTSTRACONE         80 non-null     int64
#  7   PLUSMINUS           80 non-null     int64
#  8   Z                   80 non-null     object
#  9   R                   80 non-null     object
#  10  P                   80 non-null     int64
#  11  PKTPER15            80 non-null     float64
#  12  PKTDOMPER15         80 non-null     float64
#  13  PKTWYJAZDPER15      80 non-null     float64
#  14  WIEK                80 non-null     float64
#  15  TRIUMFY             80 non-null     float64
#  16  BONUSY              80 non-null     float64
#  17  WYNIK51             80 non-null     int64
#  18  WYNIK42             80 non-null     int64
#  19  WYNIK33             80 non-null     int64
#  20  WYNIK24             80 non-null     int64
#  21  WYNIK15             80 non-null     int64
#  22  WYNIK3321           80 non-null     int64
#  23  WYNIK3330           80 non-null     int64
#  24  PKTJUNIORZY         80 non-null     float64
#  25  PKTPOL              80 non-null     float64
#  26  PKTOBCO             80 non-null     float64
#  27  PROCPKTPOL          80 non-null     float64
#  28  PROCPKTOBCO         80 non-null     float64
#  29  STARTWYG            40 non-null     float64
#  30  STARTPOR            40 non-null     float64
#  31  DYSTWYG             40 non-null     float64
#  32  DYSTPOR             40 non-null     float64
#  33  STARTBIL            40 non-null     float64
#  34  DYSTBIL             40 non-null     float64
#  35  MSCTABELA           32 non-null     float64
#  36  id                  8 non-null      float64
#  37  liczba zm takt      8 non-null      float64
#  38  śr pkt takt         8 non-null      float64
#  39  liczba zm zwyklych  8 non-null      float64
#  40  śr pkt zwyklych     8 non-null      float64
#  41  MSC TABELA          8 non-null      object
# dtypes: float64(23), int64(12), object(7)
# memory usage: 26.4+ KB

# %%
df_pgee = df_pgee.iloc[:,1:36]

# %%
df_pgee
# Out:
#    Sezon                            KLUB  PKTTABELA BONTABELA  PKTZDOBYTE  \
# 0   2024                         Wrocław         19         4         920
# 1   2024                          Leszno         11                   586
# 2   2024                          Gorzów         19         3         848
# 3   2024                       Grudziądz         14         2         641
# 4   2024                           Toruń         15         3         889
# ..   ...                             ...        ...       ...         ...
# 75  2015          MRGARDEN GKM Grudziądz         10         0         537
# 76  2015                PGE Stal Rzeszów         13         2         615
# 77  2015  MONEYmakesMONEY.pl Stal Gorzów         13         3         634
# 78  2015                     Unia Tarnów         21         4         827
# 79  2015       Spar Falubaz Zielona Góra         16         3         627
#
#     PKTSTRACONE  PLUSMINUS   Z  R   P  ...  PKTOBCO  PROCPKTPOL  PROCPKTOBCO  \
# 0           878         42  11  1   8  ...    12.55       0.727        0.273
# 1           673        -87   5  1   8  ...    18.79       0.551        0.449
# 2           860        -52  10     10  ...    19.95       0.553        0.447
# 3           677        -76   6     10  ...    26.07       0.390        0.610
# 4           909        -20   9     11  ...    12.10       0.728        0.272
# ..          ...        ...  .. ..  ..  ...      ...         ...          ...
# 75          721       -184   5  0   9  ...    10.07       0.737        0.263
# 76          641        -26   5  1   8  ...    26.71       0.392        0.608
# 77          624         10   5  0   9  ...    20.21       0.554        0.446
# 78          792         35  11  1   6  ...    27.17       0.409        0.591
# 79          628         -1   6  1   7  ...    14.64       0.673        0.327
#
#     STARTWYG  STARTPOR  DYSTWYG  DYSTPOR  STARTBIL  DYSTBIL  MSCTABELA
# 0      587.0     562.0    130.0    121.0      25.0      9.0        2.0
# 1      369.0     445.0    108.0    110.0     -76.0     -2.0        8.0
# 2      574.0     524.0    108.0    135.0      50.0    -27.0        4.0
# 3      414.0     434.0     71.0     84.0     -20.0    -13.0        5.0
# 4      527.0     633.0    155.0    117.0    -106.0     38.0        3.0
# ..       ...       ...      ...      ...       ...      ...        ...
# 75       NaN       NaN      NaN      NaN       NaN      NaN        NaN
# 76       NaN       NaN      NaN      NaN       NaN      NaN        NaN
# 77       NaN       NaN      NaN      NaN       NaN      NaN        NaN
# 78       NaN       NaN      NaN      NaN       NaN      NaN        NaN
# 79       NaN       NaN      NaN      NaN       NaN      NaN        NaN
#
# [80 rows x 35 columns]

# %%
df_pgee.dtypes
# Out:
# Sezon              object
# KLUB               object
# PKTTABELA           int64
# BONTABELA          object
# PKTZDOBYTE          int64
# PKTSTRACONE         int64
# PLUSMINUS           int64
# Z                  object
# R                  object
# P                   int64
# PKTPER15          float64
# PKTDOMPER15       float64
# PKTWYJAZDPER15    float64
# WIEK              float64
# TRIUMFY           float64
# BONUSY            float64
# WYNIK51             int64
# WYNIK42             int64
# WYNIK33             int64
# WYNIK24             int64
# WYNIK15             int64
# WYNIK3321           int64
# WYNIK3330           int64
# PKTJUNIORZY       float64
# PKTPOL            float64
# PKTOBCO           float64
# PROCPKTPOL        float64
# PROCPKTOBCO       float64
# STARTWYG          float64
# STARTPOR          float64
# DYSTWYG           float64
# DYSTPOR           float64
# STARTBIL          float64
# DYSTBIL           float64
# MSCTABELA         float64
# dtype: object

# %%
df_pgee.Sezon = df_pgee.Sezon.astype('Int64')

# %%
df_pgee["BONTABELA"].replace('',0,inplace=True)
df_pgee['BONTABELA'] = df_pgee['BONTABELA'].astype('Int64')

# %%
df_pgee["Z"].replace('',0,inplace=True)
df_pgee["R"].replace('',0,inplace=True)
df_pgee['Z'] = df_pgee['Z'].astype('Int64')
df_pgee['R'] = df_pgee['R'].astype('Int64')

# %%
df_pgee.dtypes
# Out:
# Sezon               Int64
# KLUB               object
# PKTTABELA           int64
# BONTABELA           Int64
# PKTZDOBYTE          int64
# PKTSTRACONE         int64
# PLUSMINUS           int64
# Z                   Int64
# R                   Int64
# P                   int64
# PKTPER15          float64
# PKTDOMPER15       float64
# PKTWYJAZDPER15    float64
# WIEK              float64
# TRIUMFY           float64
# BONUSY            float64
# WYNIK51             int64
# WYNIK42             int64
# WYNIK33             int64
# WYNIK24             int64
# WYNIK15             int64
# WYNIK3321           int64
# WYNIK3330           int64
# PKTJUNIORZY       float64
# PKTPOL            float64
# PKTOBCO           float64
# PROCPKTPOL        float64
# PROCPKTOBCO       float64
# STARTWYG          float64
# STARTPOR          float64
# DYSTWYG           float64
# DYSTPOR           float64
# STARTBIL          float64
# DYSTBIL           float64
# MSCTABELA         float64
# dtype: object

# %%
df_pgee.isnull().sum()
# Out:
# Sezon              0
# KLUB               0
# PKTTABELA          0
# BONTABELA          0
# PKTZDOBYTE         0
# PKTSTRACONE        0
# PLUSMINUS          0
# Z                  0
# R                  0
# P                  0
# PKTPER15           0
# PKTDOMPER15        0
# PKTWYJAZDPER15     0
# WIEK               0
# TRIUMFY            0
# BONUSY             0
# WYNIK51            0
# WYNIK42            0
# WYNIK33            0
# WYNIK24            0
# WYNIK15            0
# WYNIK3321          0
# WYNIK3330          0
# PKTJUNIORZY        0
# PKTPOL             0
# PKTOBCO            0
# PROCPKTPOL         0
# PROCPKTOBCO        0
# STARTWYG          40
# STARTPOR          40
# DYSTWYG           40
# DYSTPOR           40
# STARTBIL          40
# DYSTBIL           40
# MSCTABELA         48
# dtype: int64

# %%
df_pgee.drop(columns=["STARTWYG","STARTPOR","DYSTWYG","DYSTPOR","STARTBIL","DYSTBIL"],inplace=True)

# %%
df_pgee.loc[df_pgee["MSCTABELA"].isnull()]
# Out:
#     Sezon                                       KLUB  PKTTABELA  BONTABELA  \
# 32   2020                      Betard Sparta Wrocław         20          4
# 33   2020                           FOGO Unia Leszno         28          6
# 34   2020                     MRGARDEN GKM Grudziądz         10          1
# 35   2020               Eltrox Włókniarz Częstochowa         19          5
# 36   2020                             PGG ROW Rybnik          2          0
# 37   2020                               Motor Lublin         19          3
# 38   2020              RM Solar Falubaz Zielona Góra         20          3
# 39   2020                   Moje Bermudy Stal Gorzów         21          5
# 40   2019                           FOGO Unia Leszno         32          7
# 41   2019                      Betard Sparta Wrocław         26          6
# 42   2019                     truly.work Stal Gorzów         11          0
# 43   2019                             Get Well Toruń          5          1
# 44   2019               forBET Włókniarz Częstochowa         19          5
# 45   2019               Stelmet Falubaz Zielona Góra         20          4
# 46   2019                     Speed Car Motor Lublin         11          2
# 47   2019                     MRGARDEN GKM Grudziądz         16          3
# 48   2018                           FOGO Unia Leszno         29          7
# 49   2018                      Betard Sparta Wrocław         19          3
# 50   2018               forBET Włókniarz Częstochowa         19          2
# 51   2018                    Cash Broker Stal Gorzów         21          4
# 52   2018                             Get Well Toruń         18          5
# 53   2018                    Grupa Azoty Unia Tarnów         10          0
# 54   2018                     MRGARDEN GKM Grudziądz         12          2
# 55   2018                       Falubaz Zielona Góra         10          2
# 56   2017                      Betard Sparta Wrocław         25          6
# 57   2017                    Cash Broker Stal Gorzów         23          5
# 58   2017            Ekantor.pl Falubaz Zielona Góra         25          5
# 59   2017                           FOGO Unia Leszno         23          5
# 60   2017                             Get Well Toruń          8          2
# 61   2017                     MRGARDEN GKM Grudziądz         10          1
# 62   2017  Włókniarz Vitroszlif CrossFit Częstochowa         17          2
# 63   2017                                 ROW Rybnik          8          1
# 64   2016                      Betard Sparta Wrocław         17          2
# 65   2016            Ekantor.pl Falubaz Zielona Góra         27          6
# 66   2016                     MRGARDEN GKM Grudziądz         16          2
# 67   2016                                Unia Tarnów          7          1
# 68   2016                                 ROW Rybnik         12          3
# 69   2016                                Stal Gorzów         27          6
# 70   2016                           FOGO Unia Leszno         10          2
# 71   2016                             Get Well Toruń         22          4
# 72   2015                           FOGO Unia Leszno         29          5
# 73   2015                      Betard Sparta Wrocław         18          5
# 74   2015                                   KS Toruń         17          3
# 75   2015                     MRGARDEN GKM Grudziądz         10          0
# 76   2015                           PGE Stal Rzeszów         13          2
# 77   2015             MONEYmakesMONEY.pl Stal Gorzów         13          3
# 78   2015                                Unia Tarnów         21          4
# 79   2015                  Spar Falubaz Zielona Góra         16          3
#
#     PKTZDOBYTE  PKTSTRACONE  PLUSMINUS   Z  R   P  ...  WYNIK24  WYNIK15  \
# 32         815          783         32   9  2   7  ...       46       40
# 33         917          702        215  14  0   4  ...       33       30
# 34         561          663       -102   4  1   9  ...       47       34
# 35         619          591         28   6  2   6  ...       30       20
# 36         489          770       -281   1  0  13  ...       49       59
# 37         658          602         56   8  0   6  ...       29       29
# 38         796          802         -6   9  1   8  ...       33       48
# 39         795          737         58  10  0   8  ...       44       43
# 40         934          686        248  16  1   1  ...       29       20
# 41         836          783         53  11  0   7  ...       45       37
# 42         594          664        -70   5  1   8  ...       38       39
# 43         553          706       -153   2  0  12  ...       49       40
# 44         795          824        -29   7  2   9  ...       58       41
# 45         813          806          7  10  0   8  ...       40       41
# 46         603          657        -54   4  1   9  ...       40       35
# 47         628          630         -2   6  1   7  ...       28       30
# 48         904          716        188  13  2   3  ...       24       28
# 49         833          787         46   8  2   8  ...       52       27
# 50         799          821        -22   8  2   8  ...       54       38
# 51         834          779         55  11  1   6  ...       43       31
# 52         620          639        -19   6  1   7  ...       39       28
# 53         581          679        -98   5  0   9  ...       43       43
# 54         587          673        -86   4  2   8  ...       45       34
# 55         595          659        -64   4  0  10  ...       43       35
# 56         845          774         71  10  3   5  ...       37       42
# 57         850          768         82  10  3   5  ...       39       33
# 58         800          778         22   9  3   6  ...       36       38
# 59         861          757        104  11  2   5  ...       38       36
# 60         587          661        -74   3  0  11  ...       40       41
# 61         570          633        -63   4  1   9  ...       30       40
# 62         594          655        -61   7  1   6  ...       40       36
# 63         584          665        -81   3  1  10  ...       31       39
# 64         788          819        -31   7  1  10  ...       48       51
# 65         864          755        109  13  1   4  ...       50       30
# 66         621          639        -18   7  0   7  ...       31       39
# 67         546          713       -167   3  0  11  ...       49       44
# 68         599          658        -59   4  1   9  ...       32       40
# 69         882          724        158  13  1   4  ...       29       34
# 70         593          665        -72   3  2   9  ...       43       37
# 71         849          769         80  11  0   7  ...       39       35
# 72         861          756        105  14  1   3  ...       41       33
# 73         843          775         68   7  2   9  ...       46       35
# 74         803          810         -7   7  2   9  ...       52       39
# 75         537          721       -184   5  0   9  ...       43       57
# 76         615          641        -26   5  1   8  ...       26       41
# 77         634          624         10   5  0   9  ...       25       41
# 78         827          792         35  11  1   6  ...       55       33
# 79         627          628         -1   6  1   7  ...       41       29
#
#     WYNIK3321  WYNIK3330  PKTJUNIORZY  PKTPOL  PKTOBCO  PROCPKTPOL  \
# 32         51         37         8.56   23.28    22.00       0.514
# 33         37         42         9.44   32.94    18.00       0.647
# 34         22         56         2.14    8.43    31.64       0.210
# 35         42         33         7.69   19.08    28.54       0.401
# 36         47         34         3.00   14.79    20.14       0.423
# 37         37         36         6.36   18.14    28.86       0.386
# 38         57         43         7.67   23.94    20.28       0.541
# 39         28         40         5.35   26.82    17.59       0.604
# 40         38         47        12.17   36.28    15.61       0.699
# 41         53         39        11.94   24.39    22.06       0.525
# 42         31         50         5.77   33.69     8.54       0.798
# 43         40         43         2.29    6.79    32.71       0.172
# 44         42         45         5.83   14.83    29.33       0.336
# 45         54         49         4.28   19.50    25.67       0.432
# 46         46         29         8.71   19.79    23.29       0.459
# 47         46         48         4.21   19.29    25.57       0.430
# 48         54         47        11.59   35.12    15.12       0.699
# 49         45         54        10.67   21.39    24.89       0.462
# 50         48         49         4.61   14.61    29.78       0.329
# 51         46         59         4.53   38.71     8.00       0.829
# 52         46         36         6.38   16.54    27.23       0.378
# 53         36         31         3.46   14.92    26.77       0.358
# 54         37         44         3.14   20.36    21.57       0.486
# 55         40         32         5.36   30.57    11.93       0.719
# 56         43         45        10.33   25.83    21.11       0.550
# 57         59         42         5.39   30.39    16.83       0.644
# 58         48         64         4.06   31.22    13.22       0.703
# 59         54         42         9.50   31.89    15.94       0.667
# 60         39         30         4.93   16.93    25.00       0.404
# 61         33         46         2.43   20.64    20.07       0.507
# 62         34         38         5.43   20.93    21.50       0.493
# 63         40         43        11.14   19.21    22.50       0.461
# 64         40         38         5.44   23.22    20.56       0.530
# 65         33         48         7.83   31.11    16.89       0.648
# 66         39         38         5.29   25.57    18.79       0.576
# 67         24         53         3.71   18.00    21.00       0.462
# 68         44         34         6.57   17.79    25.00       0.416
# 69         60         35        14.00   30.22    18.78       0.617
# 70         41         31         5.57   25.57    16.79       0.604
# 71         46         50         7.72   16.94    30.22       0.359
# 72         40         51        11.11   27.50    20.33       0.575
# 73         41         42         9.11   24.56    22.28       0.524
# 74         64         32        11.83   20.44    24.17       0.458
# 75         33         33         3.57   28.29    10.07       0.737
# 76         32         42         7.21   17.21    26.71       0.392
# 77         44         25        14.57   25.07    20.21       0.554
# 78         39         53         3.50   18.78    27.17       0.409
# 79         30         45         6.29   30.14    14.64       0.673
#
#     PROCPKTOBCO  MSCTABELA
# 32        0.486        NaN
# 33        0.353        NaN
# 34        0.790        NaN
# 35        0.599        NaN
# 36        0.577        NaN
# 37        0.614        NaN
# 38        0.459        NaN
# 39        0.396        NaN
# 40        0.301        NaN
# 41        0.475        NaN
# 42        0.202        NaN
# 43        0.828        NaN
# 44        0.664        NaN
# 45        0.568        NaN
# 46        0.541        NaN
# 47        0.570        NaN
# 48        0.301        NaN
# 49        0.538        NaN
# 50        0.671        NaN
# 51        0.171        NaN
# 52        0.622        NaN
# 53        0.642        NaN
# 54        0.514        NaN
# 55        0.281        NaN
# 56        0.450        NaN
# 57        0.356        NaN
# 58        0.297        NaN
# 59        0.333        NaN
# 60        0.596        NaN
# 61        0.493        NaN
# 62        0.507        NaN
# 63        0.539        NaN
# 64        0.470        NaN
# 65        0.352        NaN
# 66        0.424        NaN
# 67        0.538        NaN
# 68        0.584        NaN
# 69        0.383        NaN
# 70        0.396        NaN
# 71        0.641        NaN
# 72        0.425        NaN
# 73        0.476        NaN
# 74        0.542        NaN
# 75        0.263        NaN
# 76        0.608        NaN
# 77        0.446        NaN
# 78        0.591        NaN
# 79        0.327        NaN
#
# [48 rows x 29 columns]

# %%
clubs_standings = {
    2015: {'MRGARDEN GKM Grudziądz': 8, 'PGE Stal Rzeszów': 7, 'MONEYmakesMONEY.pl Stal Gorzów': 6, 'Spar Falubaz Zielona Góra': 5, 
           'KS Toruń': 4, 'Betard Sparta Wrocław': 3, 'Unia Tarnów': 2, 'FOGO Unia Leszno': 1},
    2016: {'Unia Tarnów': 8, 'FOGO Unia Leszno': 7, 'ROW Rybnik': 6, 'MRGARDEN GKM Grudziądz': 5, 
           'Betard Sparta Wrocław': 4, 'Get Well Toruń': 3, 'Ekantor.pl Falubaz Zielona Góra': 2, 'Stal Gorzów': 1},
    2017: {'ROW Rybnik': 8, 'Get Well Toruń': 7, 'MRGARDEN GKM Grudziądz': 6, 'Włókniarz Vitroszlif CrossFit Częstochowa': 5, 
           'FOGO Unia Leszno': 4, 'Cash Broker Stal Gorzów': 3, 'Betard Sparta Wrocław': 2, 'Ekantor.pl Falubaz Zielona Góra': 1},
    2018: {'Grupa Azoty Unia Tarnów': 8, 'Falubaz Zielona Góra': 7, 'MRGARDEN GKM Grudziądz': 6, 'Get Well Toruń': 5, 
           'Betard Sparta Wrocław': 4, 'forBET Włókniarz Częstochowa': 3, 'Cash Broker Stal Gorzów': 2, 'FOGO Unia Leszno': 1},
    2019: {'Get Well Toruń': 8, 'truly.work Stal Gorzów': 7, 'Speed Car Motor Lublin': 6, 'MRGARDEN GKM Grudziądz': 5, 
           'forBET Włókniarz Częstochowa': 4, 'Stelmet Falubaz Zielona Góra': 3, 'Betard Sparta Wrocław': 2, 'FOGO Unia Leszno': 1},
    2020: {'PGG ROW Rybnik': 8, 'MRGARDEN GKM Grudziądz': 7, 'Motor Lublin': 6, 'Eltrox Włókniarz Częstochowa': 5, 
           'RM Solar Falubaz Zielona Góra': 4, 'Betard Sparta Wrocław': 3, 'Moje Bermudy Stal Gorzów': 2, 'FOGO Unia Leszno': 1}
}

# %%
standings_data = []
for season, clubs in clubs_standings.items():
    for club, place in clubs.items():
        standings_data.append({'Sezon': season, 'Klub': club, 'Miejsce': place})

df_standings = pd.DataFrame(standings_data)
df_standings['Miejsce'] = df_standings['Miejsce'].astype('int')

# %%
df_standings.head()
# Out:
#    Sezon                            Klub  Miejsce
# 0   2015          MRGARDEN GKM Grudziądz        8
# 1   2015                PGE Stal Rzeszów        7
# 2   2015  MONEYmakesMONEY.pl Stal Gorzów        6
# 3   2015       Spar Falubaz Zielona Góra        5
# 4   2015                        KS Toruń        4

# %%
df_standings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Sezon    48 non-null     int64
#  1   Klub     48 non-null     object
#  2   Miejsce  48 non-null     int32
# dtypes: int32(1), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
merged_df_pgee = df_pgee.merge(df_standings, left_on=['Sezon','KLUB'], right_on=['Sezon','Klub'], how='left')
merged_df_pgee['MSCTABELA'] = merged_df_pgee['MSCTABELA'].combine_first(merged_df_pgee['Miejsce'])
merged_df_pgee = merged_df_pgee.drop(columns=['Miejsce','Klub'])

# %%
merged_df_pgee
# Out:
#     Sezon                            KLUB  PKTTABELA  BONTABELA  PKTZDOBYTE  \
# 0    2024                         Wrocław         19          4         920
# 1    2024                          Leszno         11          0         586
# 2    2024                          Gorzów         19          3         848
# 3    2024                       Grudziądz         14          2         641
# 4    2024                           Toruń         15          3         889
# ..    ...                             ...        ...        ...         ...
# 75   2015          MRGARDEN GKM Grudziądz         10          0         537
# 76   2015                PGE Stal Rzeszów         13          2         615
# 77   2015  MONEYmakesMONEY.pl Stal Gorzów         13          3         634
# 78   2015                     Unia Tarnów         21          4         827
# 79   2015       Spar Falubaz Zielona Góra         16          3         627
#
#     PKTSTRACONE  PLUSMINUS   Z  R   P  ...  WYNIK24  WYNIK15  WYNIK3321  \
# 0           878         42  11  1   8  ...       52       47         38
# 1           673        -87   5  1   8  ...       30       45         36
# 2           860        -52  10  0  10  ...       50       40         62
# 3           677        -76   6  0  10  ...       40       42         38
# 4           909        -20   9  0  11  ...       54       40         54
# ..          ...        ...  .. ..  ..  ...      ...      ...        ...
# 75          721       -184   5  0   9  ...       43       57         33
# 76          641        -26   5  1   8  ...       26       41         32
# 77          624         10   5  0   9  ...       25       41         44
# 78          792         35  11  1   6  ...       55       33         39
# 79          628         -1   6  1   7  ...       41       29         30
#
#     WYNIK3330  PKTJUNIORZY  PKTPOL  PKTOBCO  PROCPKTPOL  PROCPKTOBCO  \
# 0          56         5.55   33.45    12.55       0.727        0.273
# 1          42         5.36   23.07    18.79       0.551        0.449
# 2          48         7.58   24.68    19.95       0.553        0.447
# 3          27         6.53   16.67    26.07       0.390        0.610
# 4          67         4.55   32.35    12.10       0.728        0.272
# ..        ...          ...     ...      ...         ...          ...
# 75         33         3.57   28.29    10.07       0.737        0.263
# 76         42         7.21   17.21    26.71       0.392        0.608
# 77         25        14.57   25.07    20.21       0.554        0.446
# 78         53         3.50   18.78    27.17       0.409        0.591
# 79         45         6.29   30.14    14.64       0.673        0.327
#
#     MSCTABELA
# 0         2.0
# 1         8.0
# 2         4.0
# 3         5.0
# 4         3.0
# ..        ...
# 75        8.0
# 76        7.0
# 77        6.0
# 78        2.0
# 79        5.0
#
# [80 rows x 29 columns]

# %%
merged_df_pgee['MSCTABELA'].isnull().sum()
# Out:
# 0

# %%
df_pgee = merged_df_pgee

# %%
df_pgee["MSCTABELA"] = df_pgee["MSCTABELA"].astype(int)

# %%
df_pgee["KLUB"].unique()
# Out:
# array(['Wrocław', 'Leszno', 'Gorzów', 'Grudziądz', 'Toruń', 'Częstochowa',
#        'Lublin', 'Zielona Góra', 'Betard Sparta Wrocław',
#        'FOGO Unia Leszno', 'ebut.pl Stal Gorzów', 'Cellfast Wilki Krosno',
#        'Tauron Włókniarz Częstochowa',
#        'For Nature Solutions KS Apator Toruń', 'Platinum Motor Lublin',
#        'ZOOLESZCZ GKM Grudziądz', 'Motor Lublin',
#        'zielona-energia.com Włókniarz Częstochowa', 'Arged Malesa Ostrów',
#        'Moje Bermudy Stal Gorzów', 'For Nature Solutions Apator Toruń',
#        'Eltrox Włókniarz Częstochowa', 'eWinner Apator Toruń',
#        'ZOOLESZCZ DPV LOGISTIC GKM Grudziądz',
#        'Marwis.pl Falubaz Zielona Góra', 'MRGARDEN GKM Grudziądz',
#        'PGG ROW Rybnik', 'RM Solar Falubaz Zielona Góra',
#        'truly.work Stal Gorzów', 'Get Well Toruń',
#        'forBET Włókniarz Częstochowa', 'Stelmet Falubaz Zielona Góra',
#        'Speed Car Motor Lublin', 'Cash Broker Stal Gorzów',
#        'Grupa Azoty Unia Tarnów', 'Falubaz Zielona Góra',
#        'Ekantor.pl Falubaz Zielona Góra',
#        'Włókniarz Vitroszlif CrossFit Częstochowa', 'ROW Rybnik',
#        'Unia Tarnów', 'Stal Gorzów', 'KS Toruń', 'PGE Stal Rzeszów',
#        'MONEYmakesMONEY.pl Stal Gorzów', 'Spar Falubaz Zielona Góra'],
#       dtype=object)

# %%
club_mapper = {'Wrocław':'Betard Sparta Wrocław', 'Leszno':'FOGO Unia Leszno', 'Gorzów':'Ebut.pl Stal Gorzów', 'Częstochowa':'Krono-Plast Włókniarz Częstochowa', 'Zielona Góra':'Novyhotel Falubaz Zielona Góra',
       'Toruń':'KS Apator Toruń', 'Grudziądz':'ZOOLESZCZ GKM Grudziądz', 'Lublin':'Orlen Oil Motor Lublin'}

# %%
df_pgee.loc[df_pgee['Sezon']==2024,'KLUB'] = df_pgee.loc[df_pgee['Sezon']==2024,'KLUB'].map(club_mapper)

# %%
df_pgee.loc[df_pgee['Sezon']==2024]
# Out:
#    Sezon                               KLUB  PKTTABELA  BONTABELA  PKTZDOBYTE  \
# 0   2024              Betard Sparta Wrocław         19          4         920
# 1   2024                   FOGO Unia Leszno         11          0         586
# 2   2024                Ebut.pl Stal Gorzów         19          3         848
# 3   2024            ZOOLESZCZ GKM Grudziądz         14          2         641
# 4   2024                    KS Apator Toruń         15          3         889
# 5   2024  Krono-Plast Włókniarz Częstochowa         12          2         604
# 6   2024             Orlen Oil Motor Lublin         31          7        1005
# 7   2024     Novyhotel Falubaz Zielona Góra         13          3         679
#
#    PKTSTRACONE  PLUSMINUS   Z  R   P  ...  WYNIK24  WYNIK15  WYNIK3321  \
# 0          878         42  11  1   8  ...       52       47         38
# 1          673        -87   5  1   8  ...       30       45         36
# 2          860        -52  10  0  10  ...       50       40         62
# 3          677        -76   6  0  10  ...       40       42         38
# 4          909        -20   9  0  11  ...       54       40         54
# 5          654        -50   4  2   8  ...       41       33         38
# 6          764        241  17  0   3  ...       31       27         62
# 7          757        -78   4  2  10  ...       51       38         41
#
#    WYNIK3330  PKTJUNIORZY  PKTPOL  PKTOBCO  PROCPKTPOL  PROCPKTOBCO  MSCTABELA
# 0         56         5.55   33.45    12.55       0.727        0.273          2
# 1         42         5.36   23.07    18.79       0.551        0.449          8
# 2         48         7.58   24.68    19.95       0.553        0.447          4
# 3         27         6.53   16.67    26.07       0.390        0.610          5
# 4         67         4.55   32.35    12.10       0.728        0.272          3
# 5         40         3.29   17.21    25.93       0.399        0.601          7
# 6         42         8.85   34.60    15.65       0.689        0.311          1
# 7         47         5.13   31.13    11.31       0.734        0.266          6
#
# [8 rows x 29 columns]

# %%
df_pgee["KLUB"] = df_pgee["KLUB"].str.upper()

# %%
df_pgee['BONUSY'].max()
# Out:
# 6.55

# %%
df_pgee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 79
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sezon           80 non-null     Int64
#  1   KLUB            80 non-null     object
#  2   PKTTABELA       80 non-null     int64
#  3   BONTABELA       80 non-null     Int64
#  4   PKTZDOBYTE      80 non-null     int64
#  5   PKTSTRACONE     80 non-null     int64
#  6   PLUSMINUS       80 non-null     int64
#  7   Z               80 non-null     Int64
#  8   R               80 non-null     Int64
#  9   P               80 non-null     int64
#  10  PKTPER15        80 non-null     float64
#  11  PKTDOMPER15     80 non-null     float64
#  12  PKTWYJAZDPER15  80 non-null     float64
#  13  WIEK            80 non-null     float64
#  14  TRIUMFY         80 non-null     float64
#  15  BONUSY          80 non-null     float64
#  16  WYNIK51         80 non-null     int64
#  17  WYNIK42         80 non-null     int64
#  18  WYNIK33         80 non-null     int64
#  19  WYNIK24         80 non-null     int64
#  20  WYNIK15         80 non-null     int64
#  21  WYNIK3321       80 non-null     int64
#  22  WYNIK3330       80 non-null     int64
#  23  PKTJUNIORZY     80 non-null     float64
#  24  PKTPOL          80 non-null     float64
#  25  PKTOBCO         80 non-null     float64
#  26  PROCPKTPOL      80 non-null     float64
#  27  PROCPKTOBCO     80 non-null     float64
#  28  MSCTABELA       80 non-null     int32
# dtypes: Int64(4), float64(11), int32(1), int64(12), object(1)
# memory usage: 18.8+ KB

# %%
df_pgee.iloc[:,10:13] = df_pgee.iloc[:,10:13].apply(lambda x: round(x,2))

# %%
print(df_pgee[['PKTPER15', 'PKTDOMPER15', 'PKTWYJAZDPER15','WIEK','TRIUMFY','BONUSY','PKTJUNIORZY',
               'PKTPOL','PKTOBCO','PROCPKTPOL','PROCPKTOBCO']].max())
# Out:
# PKTPER15          51.890
# PKTDOMPER15       55.890
# PKTWYJAZDPER15    49.710
# WIEK              31.820
# TRIUMFY           10.200
# BONUSY             6.550
# PKTJUNIORZY       14.570
# PKTPOL            39.100
# PKTOBCO           32.710
# PROCPKTPOL         0.829
# PROCPKTOBCO        0.828
# dtype: float64

# %%
# Database connection parameters
server_name = 'DESKTOP-F00PL4B\SQLEXPRESS01'
database_name = 'PortfolioProject'
table_name = 'fctPGEEResults'

# SQLAlchemy engine creation with Windows Authentication
engine = create_engine(f"mssql+pyodbc://@{server_name}/{database_name}?trusted_connection=yes&driver=ODBC+Driver+17+for+SQL+Server")

# Insert DataFrame into the existing table with column mapping
df_pgee.to_sql(name=table_name, con=engine, if_exists='append', index=False)

# Close the database connection
engine.dispose()
